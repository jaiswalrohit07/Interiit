# %%
import yfinance as yf

# %%
import pandas as pd
import numpy as np
import datetime

# %%
start = datetime.date(2021, 7, 1)
end = datetime.date(2023, 1, 31)

df_nifty = yf.download("^NSEI", start, end, interval="1h" )
df_indvix = yf.download('^INDIAVIX' , start  , end , interval = '1h')
df_bank = yf.download("^NSEBANK", start, end, interval="1h" )
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
len(df_nifty)
# Out:
# 2745

# %%
len(df_indvix)
# Out:
# 2744

# %%
df_nifty, df_indvix
# Out:
# (                                   Open          High           Low  \
#  2021-07-01 09:15:00+05:30  15755.049805  15755.049805  15708.099609
#  2021-07-01 10:15:00+05:30  15731.599609  15735.650391  15685.549805
#  2021-07-01 11:15:00+05:30  15698.250000  15713.250000  15690.000000
#  2021-07-01 12:15:00+05:30  15702.400391  15724.250000  15686.049805
#  2021-07-01 13:15:00+05:30  15706.349609  15732.950195  15690.349609
#  ...                                 ...           ...           ...
#  2023-01-30 12:15:00+05:30  17594.599609  17602.699219  17461.150391
#  2023-01-30 13:15:00+05:30  17459.550781  17546.599609  17406.300781
#  2023-01-30 14:15:00+05:30  17534.300781  17675.199219  17511.599609
#  2023-01-30 15:15:00+05:30  17654.800781  17672.650391  17640.000000
#  2023-01-31 15:30:00+05:30  17662.150391  17662.150391  17662.150391
#
#                                    Close     Adj Close  Volume
#  2021-07-01 09:15:00+05:30  15716.500000  15716.500000       0
# ...

# %%
df_nifty['indvix'] = df_indvix['Close']

# %%
df_nifty[['indvix' , 'Close']].plot(secondary_y = 'Close')
# Out:
# <AxesSubplot:>

# %%
df_nifty['Close'].pct_change().corr(df_indvix['Close'].pct_change())
# Out:
# -0.6602205052961972

# %%
df_bank['Close'].pct_change().std()
# Out:
# 0.004928105429264683

# %%
df_indvix['Close'].pct_change().std()
# Out:
# 0.020119484010660174

# %%
df_nifty['Close'].pct_change().std()
# Out:
# 0.003729057423544579
